# %%
import numpy as np
import pandas as pd

# %%
alldata = pd.DataFrame(columns = ['RoundNum','CourseID','RoundPos','RoundScore','RelParScore','CumParScore','PlayerID','Year','PlayerName'])
years = np.arange(1997, 2017)
alldata
# Out:
# Empty DataFrame
# Columns: [RoundNum, CourseID, RoundPos, RoundScore, RelParScore, CumParScore, PlayerID, Year, PlayerName]
# Index: []

# %%
for year in years:
    # get link to JSON data page from PGA website
    json = 'http://www.pgatour.com/data/R/014/{}/tournsum.json'.format(year)
    temp = pd.DataFrame(columns = ['RoundNum','CourseID','RoundPos','RoundScore','RelParScore','CumParScore','PlayerID','Year','PlayerName'])
    data =
# Out:
# http://www.pgatour.com/data/R/014/1997/tournsum.json
# http://www.pgatour.com/data/R/014/1998/tournsum.json
# http://www.pgatour.com/data/R/014/1999/tournsum.json
# http://www.pgatour.com/data/R/014/2000/tournsum.json
# http://www.pgatour.com/data/R/014/2001/tournsum.json
# http://www.pgatour.com/data/R/014/2002/tournsum.json
# http://www.pgatour.com/data/R/014/2003/tournsum.json
# http://www.pgatour.com/data/R/014/2004/tournsum.json
# http://www.pgatour.com/data/R/014/2005/tournsum.json
# http://www.pgatour.com/data/R/014/2006/tournsum.json
# http://www.pgatour.com/data/R/014/2007/tournsum.json
# http://www.pgatour.com/data/R/014/2008/tournsum.json
# http://www.pgatour.com/data/R/014/2009/tournsum.json
# http://www.pgatour.com/data/R/014/2010/tournsum.json
# http://www.pgatour.com/data/R/014/2011/tournsum.json
# http://www.pgatour.com/data/R/014/2012/tournsum.json
# http://www.pgatour.com/data/R/014/2013/tournsum.json
# http://www.pgatour.com/data/R/014/2014/tournsum.json
# ...

# %%
from pandas.io.json import json_normalize
import json
import requests

# %%
data = json.loads(requests.get('http://www.pgatour.com/data/R/014/2017/tournsum.json').text)
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-22-a27b21df2873> in <module>()
#       2 #data = pd.read_json('http://www.pgatour.com/data/R/014/2017/tournsum.json')
#       3 for d in data['years']:
# ----> 4     print(json.dumps(d.keys))
#
# C:\Users\cheiser\AppData\Local\Continuum\Anaconda3\lib\json\__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     228         cls is None and indent is None and separators is None and
#     229         default is None and not sort_keys and not kw):
# --> 230         return _default_encoder.encode(obj)
#     231     if cls is None:
#     232         cls = JSONEncoder
#
# C:\Users\cheiser\AppData\Local\Continuum\Anaconda3\lib\json\encoder.py in encode(self, o)
#     196         # exceptions aren't as detailed.  The list call should be roughly
#     197         # equivalent to the PySequence_Fast that ''.join() would do.
# ...

# %%
concisedata = data['years'][0]['tours'][0]['trns'][0]

# %%
concisedata['plrs'][0]
# Out:
# {'EventFedExPoints': '600.00',
#  'alphaKeyFirst': 'SERGIO',
#  'alphaKeyLast': 'GARCIA',
#  'alphaKeyMiddle': '',
#  'finPos': {'eventStatus': '',
#   'finPosNum': '1',
#   'finPosValue': '1',
#   'tied': 'N'},
#  'money': '1,980,000.00',
#  'name': {'amateur': 'N',
#   'exemption': 'xemption',
#   'exemptionCode': '000',
#   'first': 'Sergio',
#   'last': 'Garcia',
#   'member': 'M',
#   'middle': '',
#   'nickname': ''},
#  'plrNum': '21209',
#  'primaryTour': 'r',
#  'relParScrTot': '-9',
#  'rnds': [{'courseNum': '014',
#    'cumParScr': '-1',
#    'relParScr': '-1',
#    'rndNum': 'Round 1',
#    'rndPos': 'T4',
#    'rndScr': '71'},
#   {'courseNum': '014',
#    'cumParScr': '-4',
#    'relParScr': '-3',
#    'rndNum': 'Round 2',
#    'rndPos': 'T1',
#    'rndScr': '69'},
#   {'courseNum': '014',
#    'cumParScr': '-6',
#    'relParScr': '-2',
#    'rndNum': 'Round 3',
#    'rndPos': 'T1',
#    'rndScr': '70'},
#   {'courseNum': '014',
#    'cumParScr': '-9',
# ...

# %%
# initialize dictionary for dumping info into
out = {'RoundNum':[], 'CourseID':[], 'RoundPos':[], 'RoundScore':[], 'PlayerID':[], 'Year':[], 'PlayerName':[]}

# %%
year = 2017 # I would have this one saved before looping - higher loop level

for player in concisedata['plrs']:
    # save some stuff for later
    playername = player['name']['first'] + ' ' + player['name']['last']
    playerID = player['plrNum']
    for rnd in player['rnds']:
        out['Year'].append(year)
        out['PlayerName'].append(playername)
        out['PlayerID'].append(playerID)
        out['RoundNum'].append(rnd['rndNum'])
        out['CourseID'].append(rnd['courseNum'])
        out['RoundPos'].append(rnd['rndPos'])
        out['RoundScore'].append(rnd['rndScr'])

# %%
# look at output
pd.DataFrame(out)
# Out:
#     CourseID PlayerID        PlayerName RoundNum RoundPos RoundScore  Year
# 0        014    21209     Sergio Garcia  Round 1       T4         71  2017
# 1        014    21209     Sergio Garcia  Round 2       T1         69  2017
# 2        014    21209     Sergio Garcia  Round 3       T1         70  2017
# 3        014    21209     Sergio Garcia  Round 4       T1         69  2017
# 4        014    22405       Justin Rose  Round 1       T4         71  2017
# 5        014    22405       Justin Rose  Round 2       T6         72  2017
# 6        014    22405       Justin Rose  Round 3       T1         67  2017
# 7        014    22405       Justin Rose  Round 4       T2         69  2017
# 8        014    26331  Charl Schwartzel  Round 1      T26         74  2017
# 9        014    26331  Charl Schwartzel  Round 2      T16         72  2017
# 10       014    26331  Charl Schwartzel  Round 3        8         68  2017
# ...

# %%
for d in data['years']:
    print(json.dumps(d, sort_keys=True,indent=4, separators=(',', ': '))) # JSON pretty print!
# Out:
# {
#     "tours": [
#         {
#             "tourCodeLC": "r",
#             "tourCodeUC": "R",
#             "tourName": "PGA TOUR",
#             "trns": [
#                 {
#                     "FedExPurse": "3,375",
#                     "courses": [
#                         {
#                             "courseName": "Augusta National GC",
#                             "courseNum": "014",
#                             "parValue": "72",
#                             "totYrds": "7435"
#                         }
#                     ],
#                     "cutRnd": "2",
#                     "cutScr": "150",
#                     "endDate": "2017-04-09",
#                     "fullName": "Masters Tournament",
#                     "lastStatDate": "2017-04-02",
#                     "numOfRnds": "4",
#                     "plrs": [
#                         {
#                             "EventFedExPoints": "600.00",
# ...

# %%
mydict = {'name':['cody'],'sport':['hockey']}

# %%
mydict['name'].append('Heiser')
mydict['sport'].append('soccer')
mydict
# Out:
# {'name': ['cody', 'Heiser', 'Heiser', 'Heiser'], 'sport': ['hockey', 'soccer']}
