# %%
import numpy as np
import pandas as pd
import json
import requests

from pga_scraper import *

# %% [markdown]
# Define function to pull round data from every player at a tournament from a given year.
# * Inputs:
#  * **tourn_ID** = PGA's designated tournament number
#  * **year** = year to grab data from
# * Output: Pandas DataFrame with round data for every player at the tournament

# %%
tourney('014', '2017')
# Out:
#     RoundNum CourseID RoundPos RoundScore PlayerID  Year        PlayerName
# 0    Round 1      014       T4         71    21209  2017     Sergio Garcia
# 1    Round 2      014       T1         69    21209  2017     Sergio Garcia
# 2    Round 3      014       T1         70    21209  2017     Sergio Garcia
# 3    Round 4      014       T1         69    21209  2017     Sergio Garcia
# 4    Round 1      014       T4         71    22405  2017       Justin Rose
# 5    Round 2      014       T6         72    22405  2017       Justin Rose
# 6    Round 3      014       T1         67    22405  2017       Justin Rose
# 7    Round 4      014       T2         69    22405  2017       Justin Rose
# 8    Round 1      014      T26         74    26331  2017  Charl Schwartzel
# 9    Round 2      014      T16         72    26331  2017  Charl Schwartzel
# 10   Round 3      014        8         68    26331  2017  Charl Schwartzel
# 11   Round 4      014        3         68    26331  2017  Charl Schwartzel
# 12   Round 1      014      T12         72    23108  2017       Matt Kuchar
# 13   Round 2      014      T13         73    23108  2017       Matt Kuchar
# 14   Round 3      014      T11         71    23108  2017       Matt Kuchar
# 15   Round 4      014       T4         67    23108  2017       Matt Kuchar
# 16   Round 1      014      T12         72    33293  2017    Thomas Pieters
# 17   Round 2      014       T1         68    33293  2017    Thomas Pieters
# 18   Round 3      014       T9         75    33293  2017    Thomas Pieters
# 19   Round 4      014       T4         68    33293  2017    Thomas Pieters
# 20   Round 1      014      T12         72    25364  2017        Paul Casey
# 21   Round 2      014      T19         75    25364  2017        Paul Casey
# 22   Round 3      014      T11         69    25364  2017        Paul Casey
# 23   Round 4      014        6         68    25364  2017        Paul Casey
# 24   Round 1      014       T4         71    32366  2017    Kevin Chappell
# 25   Round 2      014      T19         76    32366  2017    Kevin Chappell
# 26   Round 3      014      T17         70    32366  2017    Kevin Chappell
# 27   Round 4      014       T7         68    32366  2017    Kevin Chappell
# 28   Round 1      014      T12         72    28237  2017      Rory McIlroy
# 29   Round 2      014      T13         73    28237  2017      Rory McIlroy
# ..       ...      ...      ...        ...      ...   ...               ...
# 262  Round 1      014      T75         78    27064  2017   Jhonattan Vegas
# 263  Round 2      014      T78         76    27064  2017   Jhonattan Vegas
# 264  Round 1      014      T54         76    02300  2017       Ian Woosnam
# 265  Round 2      014      T78         78    02300  2017       Ian Woosnam
# 266  Round 1      014      T86         79    22378  2017   Trevor Immelman
# 267  Round 2      014      T81         76    22378  2017   Trevor Immelman
# 268  Round 1      014      T54         76    10423  2017         Mike Weir
# 269  Round 2      014      T81         79    10423  2017         Mike Weir
# 270  Round 1      014      T41         75    31323  2017     Gary Woodland
# 271  Round 2      014      T81         80    31323  2017     Gary Woodland
# 272  Round 1      014      T41         75    37455  2017        Si Woo Kim
# 273  Round 2      014      T84         81    37455  2017        Si Woo Kim
# 274  Round 1      014      T75         78    01887  2017      Mark O'Meara
# 275  Round 2      014      T84         78    01887  2017      Mark O'Meara
# 276  Round 1      014      T54         76    21498  2017   Hideto Tanihara
# 277  Round 2      014      T84         80    21498  2017   Hideto Tanihara
# 278  Round 1      014      T75         78    39958  2017     Jeunghun Wang
# 279  Round 2      014      T84         78    39958  2017     Jeunghun Wang
# 280  Round 1      014      T86         79    32200  2017    Roberto Castro
# 281  Round 2      014      T88         78    32200  2017    Roberto Castro
# 282  Round 1      014       93         82    50735  2017     Scott Gregory
# 283  Round 2      014      T88         75    50735  2017     Scott Gregory
# 284  Round 1      014       91         80    34363  2017    Tyrrell Hatton
# 285  Round 2      014       90         78    34363  2017    Tyrrell Hatton
# 286  Round 1      014      T86         79    35506  2017  Mackenzie Hughes
# 287  Round 2      014       91         80    35506  2017  Mackenzie Hughes
# 288  Round 1      014      T66         77    01717  2017        Sandy Lyle
# 289  Round 2      014       92         83    01717  2017        Sandy Lyle
# 290  Round 1      014       92         81    47061  2017         Toto Gana
# 291  Round 2      014       93         80    47061  2017         Toto Gana
#
# [292 rows x 7 columns]

# %%
courses_2017 = course_info('2017')
# Out:
# 000 is not a valid course ID
# 001 is not a valid course ID
# loading data from course #002
# loading data from course #003
# loading data from course #004
# loading data from course #005
# loading data from course #006
# loading data from course #007
# 008 is not a valid course ID
# loading data from course #009
# loading data from course #010
# loading data from course #011
# loading data from course #012
# loading data from course #013
# loading data from course #014
# 015 is not a valid course ID
# loading data from course #016
# 017 is not a valid course ID
# loading data from course #018
# loading data from course #019
# loading data from course #020
# loading data from course #021
# 022 is not a valid course ID
# loading data from course #023
# 024 is not a valid course ID
# loading data from course #025
# loading data from course #026
# loading data from course #027
# 028 is not a valid course ID
# 029 is not a valid course ID
# loading data from course #030
# 031 is not a valid course ID
# loading data from course #032
# loading data from course #033
# loading data from course #034
# 035 is not a valid course ID
# 036 is not a valid course ID
# 037 is not a valid course ID
# 038 is not a valid course ID
# 039 is not a valid course ID
# 040 is not a valid course ID
# loading data from course #041
# 042 is not a valid course ID
# 043 is not a valid course ID
# 044 is not a valid course ID
# 045 is not a valid course ID
# 046 is not a valid course ID
# loading data from course #047
# 048 is not a valid course ID
# 049 is not a valid course ID
# 050 is not a valid course ID
# 051 is not a valid course ID
# 052 is not a valid course ID
# 053 is not a valid course ID
# loading data from course #054
# 055 is not a valid course ID
# 056 is not a valid course ID
# 057 is not a valid course ID
# loading data from course #058
# 059 is not a valid course ID
# 060 is not a valid course ID
# 061 is not a valid course ID
# 062 is not a valid course ID
# 063 is not a valid course ID
# 064 is not a valid course ID
# 065 is not a valid course ID
# 066 is not a valid course ID
# 067 is not a valid course ID
# 068 is not a valid course ID
# 069 is not a valid course ID
# 070 is not a valid course ID
# 071 is not a valid course ID
# 072 is not a valid course ID
# 073 is not a valid course ID
# 074 is not a valid course ID
# 075 is not a valid course ID
# 076 is not a valid course ID
# 077 is not a valid course ID
# 078 is not a valid course ID
# 079 is not a valid course ID
# 080 is not a valid course ID
# 081 is not a valid course ID
# 082 is not a valid course ID
# 083 is not a valid course ID
# 084 is not a valid course ID
# 085 is not a valid course ID
# 086 is not a valid course ID
# 087 is not a valid course ID
# 088 is not a valid course ID
# 089 is not a valid course ID
# 090 is not a valid course ID
# 091 is not a valid course ID
# 092 is not a valid course ID
# 093 is not a valid course ID
# 094 is not a valid course ID
# 095 is not a valid course ID
# 096 is not a valid course ID
# 097 is not a valid course ID
# 098 is not a valid course ID
# 099 is not a valid course ID
# loading data from course #100

# %%
courses_2017.CourseID.astype('str')
# Out:
# 0     704
# 1     510
# 2     004
# 3     005
# 4     006
# 5     500
# 6     009
# 7     734
# 8     011
# 9     012
# 10    752
# 11    014
# 12    656
# 13    714
# 14    019
# 15    729
# 16    021
# 17    023
# 18    513
# 19    236
# 20    238
# 21    669
# 22    032
# 23    241
# 24    503
# 25    770
# 26    538
# 27    746
# 28    678
# 29    541
# Name: CourseID, dtype: object

# %% [markdown]
# The following will be the big function that loops through years for a given tournament

# %%
years = [x for x in range(1997, 2019)] # define years to grab data from

# %%
temp = pd.DataFrame(columns = ['RoundNum','CourseID','RoundPos','RoundScore','RelParScore','CumParScore','PlayerID','Year','PlayerName'])
for year in years:
    for course_ID in courses_2017.CourseID:
        data = temp.append(tourney(str(course_ID), str(year)))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-33-e6956f6c1489> in <module>()
#       2 for year in years:
#       3     for course_ID in courses_2017.CourseID:
# ----> 4         data = temp.append(tourney(str(course_ID), str(year)))
#
# ~/git/pga-data/pga_scraper.py in tourney(course_ID, year)
#      13                 year = year of tournament to grab data from
#      14 	'''
# ---> 15         tourn = requests.get('http://www.pgatour.com/data/R/{}/{}/tournsum.json'.format(course_ID, year)).json() # load JSON for tournament and year specified
#      16         data = tourn['years'][0]['tours'][0]['trns'][0] # ignore extraneous metadata for now, get straight to the meat
#      17
#
# ~/.virtualenvs/pga_scraper/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     890                     # used.
#     891                     pass
# --> 892         return complexjson.loads(self.text, **kwargs)
#     893
#     894     @property
#
# /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /usr/local/Cellar/python/3.6.5/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 2 column 1 (char 2)

# %%
from bs4 import BeautifulSoup
import requests

# %%
def get_links():
  urls = []
  base_url = "http://www.pgatour.com/stats/stat.109."
  for i in range(1980,2019):
      urls.append((base_url + str(i) + ".html", i))
  return urls

# %%
get_links()
# Out:
# [('http://www.pgatour.com/stats/stat.109.1980.html', 1980),
#  ('http://www.pgatour.com/stats/stat.109.1981.html', 1981),
#  ('http://www.pgatour.com/stats/stat.109.1982.html', 1982),
#  ('http://www.pgatour.com/stats/stat.109.1983.html', 1983),
#  ('http://www.pgatour.com/stats/stat.109.1984.html', 1984),
#  ('http://www.pgatour.com/stats/stat.109.1985.html', 1985),
#  ('http://www.pgatour.com/stats/stat.109.1986.html', 1986),
#  ('http://www.pgatour.com/stats/stat.109.1987.html', 1987),
#  ('http://www.pgatour.com/stats/stat.109.1988.html', 1988),
#  ('http://www.pgatour.com/stats/stat.109.1989.html', 1989),
#  ('http://www.pgatour.com/stats/stat.109.1990.html', 1990),
#  ('http://www.pgatour.com/stats/stat.109.1991.html', 1991),
#  ('http://www.pgatour.com/stats/stat.109.1992.html', 1992),
#  ('http://www.pgatour.com/stats/stat.109.1993.html', 1993),
#  ('http://www.pgatour.com/stats/stat.109.1994.html', 1994),
#  ('http://www.pgatour.com/stats/stat.109.1995.html', 1995),
#  ('http://www.pgatour.com/stats/stat.109.1996.html', 1996),
#  ('http://www.pgatour.com/stats/stat.109.1997.html', 1997),
#  ('http://www.pgatour.com/stats/stat.109.1998.html', 1998),
#  ('http://www.pgatour.com/stats/stat.109.1999.html', 1999),
#  ('http://www.pgatour.com/stats/stat.109.2000.html', 2000),
#  ('http://www.pgatour.com/stats/stat.109.2001.html', 2001),
#  ('http://www.pgatour.com/stats/stat.109.2002.html', 2002),
#  ('http://www.pgatour.com/stats/stat.109.2003.html', 2003),
#  ('http://www.pgatour.com/stats/stat.109.2004.html', 2004),
#  ('http://www.pgatour.com/stats/stat.109.2005.html', 2005),
#  ('http://www.pgatour.com/stats/stat.109.2006.html', 2006),
#  ('http://www.pgatour.com/stats/stat.109.2007.html', 2007),
#  ('http://www.pgatour.com/stats/stat.109.2008.html', 2008),
#  ('http://www.pgatour.com/stats/stat.109.2009.html', 2009),
#  ('http://www.pgatour.com/stats/stat.109.2010.html', 2010),
#  ('http://www.pgatour.com/stats/stat.109.2011.html', 2011),
#  ('http://www.pgatour.com/stats/stat.109.2012.html', 2012)]

# %%
def scrape_money_leaders_year(url):
  #Downloads the money winners by year for the PGA tour
  #using Requests
  response = requests.get(url)
  soup = BeautifulSoup(response.content, 'lxml')
  money = []
  for item in soup.findAll("td", "hidden-small")[4::3]:
      money.append(item.text)
  return money

# %%
scrape_money_leaders_year(get_links()[-1][0])
# Out:
# ['$8,457,352',
#  '$8,130,678',
#  '$8,094,489',
#  '$7,094,047',
#  '$5,793,748',
#  '$5,620,138',
#  '$5,443,841',
#  '$5,376,417',
#  '$5,087,461',
#  '$5,065,842',
#  '$5,006,267',
#  '$4,595,187',
#  '$4,410,296',
#  '$4,315,200',
#  '$4,235,237',
#  '$4,069,464',
#  '$4,047,538',
#  '$3,992,678',
#  '$3,963,962',
#  '$3,935,147',
#  '$3,916,001',
#  '$3,771,221',
#  '$3,641,771',
#  '$3,622,607',
#  '$3,578,316',
#  '$3,541,151',
#  '$3,486,407',
#  '$3,108,907',
#  '$2,972,285',
#  '$2,962,641',
#  '$2,793,536',
#  '$2,768,863',
#  '$2,733,463',
#  '$2,714,450',
#  '$2,710,736',
#  '$2,700,018',
#  '$2,699,150',
#  '$2,687,477',
#  '$2,680,487',
#  '$2,642,179',
#  '$2,599,264',
#  '$2,493,163',
#  '$2,485,203',
#  '$2,449,869',
#  '$2,449,707',
#  '$2,448,970',
#  '$2,448,920',
#  '$2,387,382',
#  '$2,291,128',
#  '$2,276,114',
#  '$2,237,641',
#  '$2,179,725',
#  '$2,152,501',
#  '$2,027,312',
#  '$1,986,608',
#  '$1,978,906',
#  '$1,976,198',
#  '$1,957,635',
#  '$1,943,360',
#  '$1,932,488',
#  '$1,920,340',
#  '$1,887,208',
#  '$1,882,337',
#  '$1,881,787',
#  '$1,824,111',
#  '$1,797,715',
#  '$1,794,431',
#  '$1,731,493',
#  '$1,721,763',
#  '$1,720,097',
#  '$1,710,179',
#  '$1,676,695',
#  '$1,641,260',
#  '$1,608,338',
#  '$1,595,942',
#  '$1,529,289',
#  '$1,523,642',
#  '$1,516,438',
#  '$1,497,655',
#  '$1,496,253',
#  '$1,484,445',
#  '$1,476,838',
#  '$1,471,462',
#  '$1,466,224',
#  '$1,441,205',
#  '$1,424,030',
#  '$1,402,833',
#  '$1,400,637',
#  '$1,386,301',
#  '$1,379,736',
#  '$1,379,544',
#  '$1,377,286',
#  '$1,358,542',
#  '$1,326,989',
#  '$1,303,610',
#  '$1,287,040',
#  '$1,269,386',
#  '$1,243,309',
#  '$1,223,064',
#  '$1,198,541',
#  '$1,184,245',
#  '$1,179,616',
#  '$1,148,115',
#  '$1,147,573',
#  '$1,137,444',
#  '$1,126,057',
#  '$1,104,865',
#  '$1,089,763',
#  '$1,081,283',
#  '$1,076,678',
#  '$1,056,628',
#  '$1,046,166',
#  '$1,017,580',
#  '$981,936',
#  '$980,877',
#  '$974,538',
#  '$965,691',
#  '$944,021',
#  '$940,661',
#  '$933,327',
#  '$900,591',
#  '$899,373',
#  '$878,354',
#  '$847,304',
#  '$813,227',
#  '$801,960',
#  '$799,450',
#  '$793,140',
#  '$791,018',
#  '$789,382',
#  '$763,584',
#  '$728,296',
#  '$725,928',
#  '$708,712',
#  '$702,030',
#  '$700,783',
#  '$696,897',
#  '$660,010',
#  '$656,322',
#  '$654,200',
#  '$638,414',
#  '$622,383',
#  '$620,646',
#  '$616,758',
#  '$593,842',
#  '$582,566',
#  '$581,024',
#  '$569,391',
#  '$565,466',
#  '$563,972',
#  '$545,364',
#  '$538,681',
#  '$532,936',
#  '$523,204',
#  '$518,476',
#  '$498,341',
#  '$498,166',
#  '$482,052',
#  '$474,923',
#  '$457,337',
#  '$453,328',
#  '$449,266',
#  '$437,032',
#  '$422,260',
#  '$420,377',
#  '$420,001',
#  '$412,954',
#  '$411,606',
#  '$398,137',
#  '$391,634',
#  '$387,612',
#  '$377,265',
#  '$368,518',
#  '$364,493',
#  '$358,380',
#  '$340,591',
#  '$330,507',
#  '$309,656',
#  '$305,607',
#  '$302,593',
#  '$299,162',
#  '$296,650',
#  '$288,023',
#  '$279,019',
#  '$267,055',
#  '$251,630',
#  '$235,635',
#  '$234,510',
#  '$229,439',
#  '$219,405',
#  '$209,216',
#  '$206,764',
#  '$201,136',
#  '$187,399',
#  '$184,057',
#  '$183,806',
#  '$179,459',
#  '$175,235',
#  '$174,039',
#  '$170,673',
#  '$145,725',
#  '$130,200',
#  '$119,407',
#  '$115,379',
#  '$110,276',
#  '$108,500',
#  '$102,868',
#  '$97,920',
#  '$95,334',
#  '$93,947',
#  '$93,260',
#  '$91,100',
#  '$90,993',
#  '$89,104',
#  '$85,595',
#  '$82,161',
#  '$81,989',
#  '$76,817',
#  '$76,616',
#  '$69,125',
#  '$68,604',
#  '$60,851',
#  '$46,962',
#  '$46,200',
#  '$44,516',
#  '$43,620',
#  '$43,134',
#  '$42,810',
#  '$41,566',
#  '$39,508',
#  '$39,000',
#  '$37,814',
#  '$33,348',
#  '$24,878',
#  '$24,448',
#  '$21,344',
#  '$21,278',
#  '$20,353',
#  '$20,353',
#  '$19,970',
#  '$18,998',
#  '$18,362',
#  '$18,067',
#  '$15,598',
#  '$15,431',
#  '$14,136',
#  '$13,000',
#  '$12,694',
#  '$12,006',
#  '$10,878',
#  '$8,784',
#  '$7,595',
#  '$7,595',
#  '$7,385',
#  '$7,004',
#  '$6,930',
#  '$6,930',
#  '$5,760',
#  '$5,520']

# %%
def get_cpi():
    url = "http://www.minneapolisfed.org/community_education/teacher/calc/hist1913.cfm"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'lxml')
    info = []
    for e in soup.findAll('td')[203:]:
        info.append(e.text)
    del info[2::3] #deletes all the % change values
    cpi = dict(zip(info[::2], info[1::2]))
    return cpi

# %%
def write_csv(money_winners_list, year):
    Money_list = open("money_list_by_year.csv", 'ab')
    money_winners_list.insert(0, year)
    writer = csv.writer(Money_list, delimiter=',')
    writer.writerow(money_winners_list)
    Money_list.close()

# %%
def transpose_data():
    a = zip(*csv.reader(open("money_list_by_year.csv", "rb")))
    csv.writer(open("money_list_by_year.csv", "wb")).writerows(a)

# %%
def main():
    cpi_dict = get_cpi()
    urls = get_links()
    for url_list in urls:
        money_list = scrape_money_leaders_year(url_list[0])
        corrected_ml = [int(i.replace(',','')) * (229.6 / float(cpi_dict[str(url_list[1])])) for i in money_list]
        write_csv(corrected_ml, url_list[1])
    transpose_data()
